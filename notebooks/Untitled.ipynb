# %%
import wandb
api = wandb.Api()

# Project is specified by <entity/project-name>
runs = api.runs("joon0105/hierarchical_qmix")
summary_list = [] 
config_list = [] 
name_list = [] 
for run in runs: 
    # run.summary are the output key/values like accuracy.
    # We call ._json_dict to omit large files 
    summary_list.append(run.summary._json_dict) 

    # run.config is the input metrics.
    # We remove special values that start with _.
    config = {k:v for k,v in run.config.items() if not k.startswith('_')}
    config_list.append(config) 

    # run.name is the name of the run.
    name_list.append(run.name)       

import pandas as pd 
summary_df = pd.DataFrame.from_records(summary_list) 
config_df = pd.DataFrame.from_records(config_list) 
name_df = pd.DataFrame({'name': name_list}) 
all_df = pd.concat([name_df, config_df,summary_df], axis=1)

all_df.to_csv("project.csv")

# %%
all_df.loc[]
# Out:
#       name                 reward             map_name  memory_N  use_subq  \
# 0     SubQ  victory_if_zero_enemy  training_scenario_5         2      True
# 1     SubQ  victory_if_zero_enemy  training_scenario_5         2      True
# 2  No subQ  victory_if_zero_enemy  training_scenario_5         2     False
# 3  No subQ  victory_if_zero_enemy  training_scenario_5         2     False
# 4     SubQ  victory_if_zero_enemy  training_scenario_5         2      True
# 5     SubQ  victory_if_zero_enemy  training_scenario_5         2      True
#
#    num_runners  num_samples  reward_bias  fit_conf_tau  memory_gamma  ...  \
# 0            2            8            0           0.1          0.95  ...
# 1            2            8            0           0.1          0.95  ...
# 2            2            8            0           0.1          0.95  ...
# 3            2            8            0           0.1          0.95  ...
# 4            2            8            0           0.1          0.95  ...
# 5            2            8            0           0.1          0.95  ...
#
#    gradients/brain.qnet.mixers.mixer_2.v_gn.layers.0.relational_updater.updater0.layers.2.sigma_weight  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'bins': [-0.4130510687828064, -0.400641977787...
# 5  {'bins': [-0.1604427844285965, -0.156025722622...
#
#    gradients/brain.qnet2.mixers.mixer_0.v_gn.layers.0.relational_updater.updater0.layers.0.sigma_weight  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'bins': [-0.14801038801670074, -0.14376378059...
# 5  {'bins': [-0.2631118595600128, -0.255957245826...
#
#    gradients/brain.qnet2.mixers.mixer_0.v_gn.layers.0.relational_updater.updater0.layers.1.sigma_weight  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'bins': [-0.1411600410938263, -0.136562734842...
# 5  {'bins': [-0.2601710855960846, -0.250404208898...
#
#    gradients/brain.qnet2.mixers.mixer_0.v_gn.layers.0.relational_updater.updater0.layers.2.sigma_weight  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'bins': [-0.12634249031543732, -0.12284544110...
# 5  {'bins': [-0.3703472912311554, -0.356835067272...
#
#    gradients/brain.qnet2.mixers.mixer_1.v_gn.layers.0.relational_updater.updater0.layers.0.sigma_weight  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'bins': [-0.1098579540848732, -0.106763608753...
# 5  {'bins': [-1.5067148208618164, -1.464850544929...
#
#    gradients/brain.qnet2.mixers.mixer_1.v_gn.layers.0.relational_updater.updater0.layers.1.sigma_weight  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'bins': [-0.15614594519138336, -0.15170699357...
# 5  {'bins': [-1.6263322830200195, -1.586905360221...
#
#    gradients/brain.qnet2.mixers.mixer_1.v_gn.layers.0.relational_updater.updater0.layers.2.sigma_weight  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'bins': [-0.10865525901317596, -0.10520644485...
# 5  {'bins': [-0.6479743123054504, -0.621186673641...
#
#    gradients/brain.qnet2.mixers.mixer_2.v_gn.layers.0.relational_updater.updater0.layers.0.sigma_weight  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'bins': [-0.2500166893005371, -0.243295401334...
# 5  {'bins': [-0.18663527071475983, -0.17981955409...
#
#    gradients/brain.qnet2.mixers.mixer_2.v_gn.layers.0.relational_updater.updater0.layers.1.sigma_weight  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'bins': [-0.1940261423587799, -0.185202211141...
# 5  {'bins': [-0.18528850376605988, -0.17779889702...
#
#    gradients/brain.qnet2.mixers.mixer_2.v_gn.layers.0.relational_updater.updater0.layers.2.sigma_weight
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'bins': [-0.1531376987695694, -0.146495014429...
# 5  {'bins': [-0.22340558469295504, -0.21635568141...
#
# [6 rows x 716 columns]
